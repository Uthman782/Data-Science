# %% [markdown]
# ## Saving a figuer in our PCs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = [130,155,202,55,120,50,100]
b = ['Oxygen', 'Hedrogen','Heliam','Naitrogen','Carbon', 'Carbon Dioxyde', 'Water']
plt.pie(a, labels=b, radius=2, autopct='%0.1f%%', shadow=True)
# plt.show()
plt.savefig('E:\\fig.png',bbox_inches = 'tight', pad_inches = 0, transparent = True)
