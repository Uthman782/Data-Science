# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,5,7])

# %%
plt.plot([1,2,3,4],[11,22,33,44], color='red')

# %%
df = pd.read_csv("E:\\Local Disk E\\Data Scientist\\excel\\air_quality.csv")
df
# Out:
#   datetime                                                             \
# 0                                           5/6/2019
# 1                                           5/7/2019
# 2                                           5/7/2019
# 3                                           5/7/2019
# 4                                           5/7/2019
#
#       time  station_antwerp  station_paris   station_london
# 0  2:00:00              NaN             NaN            23.0
# 1  3:00:00             50.5            25.0            19.0
# 2  4:00:00             45.0            27.7            19.0
# 3  5:00:00              NaN            50.4            16.0
# 4  6:00:00              NaN            61.9             NaN

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'station_antwerp'}>,
#         <AxesSubplot:title={'center':'station_paris '}>],
#        [<AxesSubplot:title={'center':'station_london'}>, <AxesSubplot:>]],
#       dtype=object)
