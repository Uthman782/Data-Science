# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ar_1 = np.array([1,2,3,4,5,6,7])
ar_1
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
ar_2 = np.array([100,80,70,60,70,85,90,10,85,70,65,80,96,110])
ar_2
# Out:
# array([100,  80,  70,  60,  70,  85,  90,  10,  85,  70,  65,  80,  96,
#        110])

# %%
x = range(1,8)
y = [11,12,15,19,14,15,20]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title("WEATHER")
plt.plot(x,y, color= 'red',linewidth = 1)
plt.show()

# %%
plt.plot(ar_2, color= 'orange',linewidth = 3, linestyle='dashed')
plt.show()

# %%
plt.plot(x,y, color = '#aabbcc', linewidth=3)
