# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('E:\\Local Disk E\\Data Scientist\\Complete Machine Learning & Data Science Bootcamp 2021\\8. Matplotlib Plotting and Data Visualization\\13.1 heart-disease.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# df['age'].plot.hist(figsize=(10,6), bins=20);
df['age'].plot(figsize=(10,6), kind='hist', bins=20);

# %%
df[0:7]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
df.plot.hist(subplots=True, figsize=(12,30), bins=20);

# %% [markdown]
# ## Pyplot vs Matplotlib OO method

# %%
over_50=df[df['age']>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
ax=over_50.plot(kind='scatter', x='age', y='chol', c='target', figsize=(12, 6), cmap='plasma');
ax.set_xlim([50, 80])
# fig, ax=plt.subplots(figsize=(12, 6))
# scatter = ax.scatter(x=over_50['age'],
#                      y=over_50['chol'],
#                      c=over_50['target'],
#                      cmap='winter')
# ax.set_xlim([50, 80])
# Out:
# (50.0, 80.0)

# %%
# OO method mixed with pyplot
fig, ax=plt.subplots(figsize=(12, 6))
over_50.plot(kind='scatter', x='age', y='chol', c='target', ax = ax, cmap='summer');
ax.set_xlim([45, 100]);

# %%
# OO method from scratch
fig, ax =plt.subplots(figsize=(10, 6))
                      
scatt = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])
ax.set(title='Heart Disease and cholesterol Levels',
       xlabel='Age',
       ylabel='chol')
ax.legend(*scatt.legend_elements(), title='Target',fontsize='larger')
ax.axhline(over_50['chol'].mean(), linestyle='--');

# %%
fig, (ax0, ax1)=plt.subplots(nrows=2,
                             ncols=1,
                            figsize=(10,12))
over_50.plot(kind='scatter', x='age', y='chol', c='target', ax=ax0)
over_50.plot(kind='scatter', x='age',y='thalach', c='target' , ax=ax1);
ax0.set(title='Chol Level')
ax1.set(title='Thalach Level');

# %%
fig, ax=plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter', 
        x='age',
        y='chol',
       ax=ax);

# %%
fig, ax=plt.subplots(figsize=(10, 6))

scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])
ax.set(title='Chol Level',
       xlabel='Age',
       ylabel='Cholesterol')
ax.axhline(over_50['chol'].mean(), linestyle='--')
ax.legend(*scatter.legend_elements(), title='Target', );

# %% [markdown]
# ## Next Tut

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
fig, (ax0, ax1)=plt.subplots(figsize=(10,12),
                             nrows=2,
                             ncols=1)
# Add Data to ax0
scatter_0=ax0.scatter(x=over_50['age'], # We shall Share X (axis)
                      y=over_50['chol'],
                      c=over_50['target'])
# Customizing ax0
ax0.set(title='Heart Disease and Cholestrol Level',
        xlabel='Age',
        ylabel='Cholesterol');
ax0.axhline(over_50['chol'].mean(), linestyle='--')
ax0.legend(*scatter_0.legend_elements(), title='Target');

# Add Data to ax1
scatter_1=ax1.scatter(x=over_50['age'], 
                      y=over_50['thalach'],
                      c=over_50['target'])
# Customizing ax1
    
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Thalach Rate');
ax1.axhline(over_50['thalach'].mean(), linestyle='--')
ax1.legend(*scatter_1.legend_elements(), title='Target');

# %%
fig, (ax0, ax1)=plt.subplots(figsize=(10,12),
                             nrows=2,
                             ncols=1,
                             sharex=True)
# Add Data to ax0
scatter=ax0.scatter( x=over_50['age'], # We shall Share X (axis)
                      y=over_50['chol'],
                      c=over_50['target'])
# Customizing ax0
ax0.set(title='Heart Disease and Cholestrol Level',
        # xlabel='Age', # It will Sharing X label
        ylabel='Cholesterol');
ax0.axhline(over_50['chol'].mean(), linestyle='--')
ax0.legend(*scatter.legend_elements(), title='Target');

# Add Data to ax1
scatter=ax1.scatter(x=over_50['age'], 
                      y=over_50['thalach'],
                      c=over_50['target'])
# Customizing ax1
    
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Thalach Rate');
ax1.axhline(over_50['thalach'].mean(), linestyle='--')
ax1.legend(*scatter.legend_elements(), title='Target')
fig.suptitle('Heart Disease Analysis', fontsize=15, fontweight='bold');

# %%
fig, (ax0, ax1)=plt.subplots(nrows=1,
                             ncols=2,
                             figsize=(16,5),
                             sharex=True)
# adding some data to ax0
scatter=ax0.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'])
ax0.set(title='Cholesterol Level',

        ylabel='Cholesterol')
ax0.axhline(over_50['chol'].mean(), linestyle='-.')
ax0.legend(*scatter.legend_elements(), title='Target')

# adding somthing to ax1
scatter=ax1.scatter(x=over_50['age'],
                    y=over_50['thalach'],
                    c=over_50['target'])
ax1.axhline(over_50['thalach'].mean(), linestyle='--', c='red')
ax1.set(title='Thalach', xlabel='Age')
ax1.legend(*scatter.legend_elements(), title='Target')
fig.suptitle("Heart Disease Anlaysis");

# %%
fig, (ax0, ax1)=plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(15,12))
bar=ax0.bar(x=over_50['age'],
            height=over_50['chol'])
ax0.set(title='Cholesterol Lavel',
        xlabel='Cholesterol',
        ylabel='Age')
ax0.axhline(over_50['chol'].mean(),
           linestyle='-.',
           color='#ffff')
ax0.grid()
bar=ax1.bar(x=over_50['age'],
            height=over_50['thalach'])
ax1.set(title='Cholesterol Lavel',
        xlabel='Thalach',
        ylabel='Age')
ax1.axhline(over_50['thalach'].mean(),
            linestyle='--', 
            c='#ffff')
ax1.grid()

# %%
plt.style.use('seaborn-')
fig, (ax0, ax1)=plt.subplots(nrows=1,
                             ncols=2,
                             figsize=(16,5),
                             sharex=True)
# adding some data to ax0
scatter=ax0.scatter(x=over_50['age'],
                    y=over_50['chol'],
                    c=over_50['target'])
ax0.set(title='Cholesterol Level',

        ylabel='Cholesterol')
ax0.axhline(over_50['chol'].mean(), linestyle='-.')
ax0.legend(*scatter.legend_elements(), title='Target')

# adding somthing to ax1
scatter=ax1.scatter(x=over_50['age'],
                    y=over_50['thalach'],
                    c=over_50['target'])
ax1.axhline(over_50['thalach'].mean(), linestyle='--', c='red')
ax1.set(title='Thalach', xlabel='Age')
ax1.legend(*scatter.legend_elements(), title='Target')
fig.suptitle("Heart Disease Anlaysis");

# %%
plt.style.use('tableau-colorblind10')
fig, (ax0, ax1)=plt.subplots(figsize=(15,15),
                             nrows=2,
                             ncols=1,
                             sharex=True)
# Add Data to ax0
scatter=ax0.scatter(x=over_50['age'], # We shall Share X (axis)
                    y=over_50['chol'],
                    c=over_50['target'],
                    cmap='winter')
# Customizing ax0
ax0.set(title='Heart Disease and Cholestrol Level',
        # xlabel='Age', # It will Sharing X label
        ylabel='Cholesterol');
ax0.axhline(over_50['chol'].mean(), linestyle='--')
ax0.legend(*scatter.legend_elements(), title='Target');

# Add Data to ax1
scatter=ax1.scatter(x=over_50['age'], 
                    y=over_50['thalach'],
                    c=over_50['target'],
                    cmap='summer')
# Customizing ax1
    
ax1.set(title='Heart Disease and Max Heart Rate',
       xlabel='Age',
       ylabel='Thalach Rate')
ax1.set_xlim([50, 80])
ax1.set_ylim([60,200])
ax1.axhline(over_50['thalach'].mean(), linestyle='--')
ax1.legend(*scatter.legend_elements(), title='Target')
fig.suptitle('Heart Disease Analysis', fontsize=15, fontweight='bold');
