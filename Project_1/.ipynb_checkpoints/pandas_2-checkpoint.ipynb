# %%
import pandas as pd
# df = pd.read_csv('C:\\Users\\Usman Khan\\Downloads\\weather.csv')
# df
df_2 = pd.read_csv('C:\\Users\\Usman Khan\\Downloads\\weather_2.csv')
df_2
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df_2.shape
# Out:
# (28, 12)

# %%
r, c = df_2.shape
c
# Out:
# 12

# %%
df_2.head(3)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees  Unnamed: 11
# 0             281          NaN
# 1             275          NaN
# 2             277          NaN

# %%
df_2.tail(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
#
#     WindDirDegrees  Unnamed: 11
# 26             311          NaN
# 27             234          NaN

# %%
df_2[2:6]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
#
#    WindDirDegrees  Unnamed: 11
# 2             277          NaN
# 3             345          NaN
# 4             333          NaN
# 5             259          NaN

# %%
df_2[0:11:2]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 2    1/3/2016           40        21        47                 29.86
# 4    1/5/2016           20        -3        41                 30.57
# 6    1/7/2016           39        11        33                 30.28
# 8    1/9/2016           44        38        77                 30.16
# 10  1/11/2016           33         8        37                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0                10           8.0               0           5    NaN
# 2                10           8.0               0           1    NaN
# 4                10           5.0               0           0    NaN
# 6                10           2.0               0           3    NaN
# 8                 9           8.0               T           8   Rain
# ...

# %%
df_2.columns[0:4]
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity'], dtype='object')

# %%
df_2.EST[0:5]
# df_2['EST'][1:5]
# Out:
# 0    1/1/2016
# 1    1/2/2016
# 2    1/3/2016
# 3    1/4/2016
# 4    1/5/2016
# Name: EST, dtype: object

# %%
df_2[['EST', 'WindSpeedMPH', 'DewPoint', 'Events']][1:5]
# Out:
#         EST  WindSpeedMPH  DewPoint Events
# 1  1/2/2016           7.0        18    NaN
# 2  1/3/2016           8.0        21    NaN
# 3  1/4/2016           9.0         9    NaN
# 4  1/5/2016           5.0        -3    NaN

# %%
df_2[['EST', 'WindSpeedMPH', 'DewPoint', 'Events']][1:5].describe()
# Out:
#        WindSpeedMPH   DewPoint
# count      4.000000   4.000000
# mean       7.250000  11.250000
# std        1.707825  10.781929
# min        5.000000  -3.000000
# 25%        6.500000   6.000000
# 50%        7.500000  13.500000
# 75%        8.250000  18.750000
# max        9.000000  21.000000

# %%
df_2[df_2['Temperature']>=30]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# ...

# %%
df_2[['EST', 'Temperature', 'Events']][df_2.Temperature>=30][7:14]
# Out:
#           EST  Temperature    Events
# 9   1/10/2016           50      Rain
# 10  1/11/2016           33       NaN
# 11  1/12/2016           35       NaN
# 13  1/14/2016           30       NaN
# 14  1/15/2016           43       NaN
# 15  1/16/2016           47      Rain
# 16  1/17/2016           36  Fog-Snow

# %%
df_2['EST'][df_2['Temperature']>=30]
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 19    1/20/2016
# 20    1/21/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# Name: EST, dtype: object

# %%
df_2[df_2['Temperature']==df_2.Temperature.min()]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees  Unnamed: 11
# 4             333          NaN

# %%
df_2[df_2['Temperature']==df_2.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees  Unnamed: 11
# 9             109          NaN

# %%
df_2[['EST', 'Temperature']][df_2['Temperature']==df_2.Temperature.max()]
# Out:
#          EST  Temperature
# 9  1/10/2016           50

# %%
df_2.set_index('Temperature', inplace=True)
df_2
# Out:
#                    EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 38            1/1/2016        23        52                 30.03
# 36            1/2/2016        18        46                 30.02
# 40            1/3/2016        21        47                 29.86
# 25            1/4/2016         9        44                 30.05
# 20            1/5/2016        -3        41                 30.57
# 33            1/6/2016         4        35                 30.50
# 39            1/7/2016        11        33                 30.28
# 39            1/8/2016        29        64                 30.20
# 44            1/9/2016        38        77                 30.16
# 50           1/10/2016        46        71                 29.59
# 33           1/11/2016         8        37                 29.92
# 35           1/12/2016        15        53                 29.85
# 26           1/13/2016         4        42                 29.94
# ...

# %%
# df_2.reset_index(inplace=True)

# %%
df_2.loc[25]
# Out:
#                    EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 25            1/4/2016         9        44                 30.05
# 25           1/18/2016         6        53                 29.83
#
#              VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# Temperature
# 25                        10           9.0               0           3    NaN
# 25                         9          12.0               T           2   Snow
#
#              WindDirDegrees  Unnamed: 11
# Temperature
# 25                      345          NaN
# 25                      293          NaN
