# %%
import pandas as pd

# %%
df = pd.read_csv("E:weatherData.csv")
df
# Out:
#           day    city  temperature  windspeed events
# 0   3/10/2023    swat           24          9  Sunny
# 1   3/11/2023    swat           25         11  Sunny
# 2   3/12/2023    swat           23         12   Rain
# 3   3/13/2023    swat           21          8   Snow
# 4   3/10/2023   kanju           26          6   Rain
# 5   3/11/2023   kanju           27          4   Rain
# 6   3/12/2023   kanju           23          5   Snow
# 7   3/13/2023   kanju           22          7  Sunny
# 8   3/10/2023  mardan           28         12   Rain
# 9   3/11/2023  mardan           29         10   Rain
# 10  3/12/2023  mardan           30          9  Sunny
# 11  3/13/2023  mardan           33          8  Sunny

# %%
df_1 = pd.crosstab([df.day, df.city], [df.events])
df_1
# Out:
# events            Rain  Snow  Sunny
# day       city
# 3/10/2023 kanju      1     0      0
#           mardan     1     0      0
#           swat       0     0      1
# 3/11/2023 kanju      1     0      0
#           mardan     1     0      0
#           swat       0     0      1
# 3/12/2023 kanju      0     1      0
#           mardan     0     0      1
#           swat       1     0      0
# 3/13/2023 kanju      0     0      1
#           mardan     0     0      1
#           swat       0     1      0

# %%
df
# Out:
#           day    city  temperature  windspeed events
# 0   3/10/2023    swat           24          9  Sunny
# 1   3/11/2023    swat           25         11  Sunny
# 2   3/12/2023    swat           23         12   Rain
# 3   3/13/2023    swat           21          8   Snow
# 4   3/10/2023   kanju           26          6   Rain
# 5   3/11/2023   kanju           27          4   Rain
# 6   3/12/2023   kanju           23          5   Snow
# 7   3/13/2023   kanju           22          7  Sunny
# 8   3/10/2023  mardan           28         12   Rain
# 9   3/11/2023  mardan           29         10   Rain
# 10  3/12/2023  mardan           30          9  Sunny
# 11  3/13/2023  mardan           33          8  Sunny

# %%
df[['city','temperature','events']][df.temperature>=25]
# Out:
#       city  temperature events
# 1     swat           25  Sunny
# 4    kanju           26   Rain
# 5    kanju           27   Rain
# 8   mardan           28   Rain
# 9   mardan           29   Rain
# 10  mardan           30  Sunny
# 11  mardan           33  Sunny

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df[['temperature', 'windspeed']][df.city=='swat'].hist()
print('Swat')
# Out:
# Swat
